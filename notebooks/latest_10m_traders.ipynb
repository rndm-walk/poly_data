# %% [markdown]
# # Latest 10M Polymarket Trades
#
# Quick exploration of the most recent 10 million processed trades (current snapshot ends 2025-11-16).
# Use this notebook to explore wallet activity, directionality, and market concentration before exporting for GPT-powered profiling.

# %%
from __future__ import annotations

from pathlib import Path
import sys

import pandas as pd
import polars as pl

PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from poly_utils.utils import get_markets

# %%
LATEST_PARQUET = Path("../processed/latest_10000000_trades.parquet")
TRADES_TO_ANALYZE = 10_000_000

if not LATEST_PARQUET.exists():
    raise FileNotFoundError(f"Could not find {LATEST_PARQUET}. Run scripts/extract_latest_trades.py first.")

latest_trades = pl.scan_parquet(LATEST_PARQUET)
latest_trades
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>Parquet SCAN [../processed/latest_10000000_trades.parquet]<p></p>PROJECT */11 COLUMNS<p></p>ESTIMATED ROWS: 10000000</div>

# %%
print('Columns:', latest_trades.columns)
latest_trades.head(5).collect()
# Out:
# Columns: ['timestamp', 'market_id', 'maker', 'taker', 'nonusdc_side', 'maker_direction', 'taker_direction', 'price', 'usd_amount', 'token_amount', 'transactionHash']
# /tmp/ipykernel_25754/278431808.py:1: PerformanceWarning: Determining the column names of a LazyFrame requires resolving its schema, which is a potentially expensive operation. Use `LazyFrame.collect_schema().names()` to get the column names without this warning.
#   print('Columns:', latest_trades.columns)
# shape: (5, 11)
# ┌────────────┬───────────┬────────────┬────────────┬───┬───────┬───────────┬───────────┬───────────┐
# │ timestamp  ┆ market_id ┆ maker      ┆ taker      ┆ … ┆ price ┆ usd_amoun ┆ token_amo ┆ transacti │
# │ ---        ┆ ---       ┆ ---        ┆ ---        ┆   ┆ ---   ┆ t         ┆ unt       ┆ onHash    │
# │ str        ┆ i64       ┆ str        ┆ str        ┆   ┆ f64   ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆            ┆            ┆   ┆       ┆ f64       ┆ f64       ┆ str       │
# ╞════════════╪═══════════╪════════════╪════════════╪═══╪═══════╪═══════════╪═══════════╪═══════════╡
# │ 2025-11-09 ┆ 668921    ┆ 0x537494c5 ┆ 0x4bfb41d5 ┆ … ┆ 0.91  ┆ 18.2      ┆ 20.0      ┆ 0x178cdb7 │
# │ T05:16:03. ┆           ┆ 4dee916253 ┆ b3570defd0 ┆   ┆       ┆           ┆           ┆ 3436b1d2a │
# │ 000000     ┆           ┆ 4675712f2e ┆ 3c39a9a4d8 ┆   ┆       ┆           ┆           ┆ d5189b87b │
# │            ┆           ┆ …          ┆ …          ┆   ┆       ┆           ┆           ┆ 28c…      │
# │ 2025-11-09 ┆ 668921    ┆ 0x6031b6ee ┆ 0x537494c5 ┆ … ┆ 0.91  ┆ 9.1       ┆ 10.0      ┆ 0x178cdb7 │
# │ T05:16:03. ┆           ┆ d1c97e853c ┆ 4dee916253 ┆   ┆       ┆           ┆           ┆ 3436b1d2a │
# │ 000000     ┆           ┆ 6e0f03ad3c ┆ 4675712f2e ┆   ┆       ┆           ┆           ┆ d5189b87b │
# │            ┆           ┆ …          ┆ …          ┆   ┆       ┆           ┆           ┆ 28c…      │
# │ 2025-11-09 ┆ 668919    ┆ 0x6031b6ee ┆ 0xca85f4b9 ┆ … ┆ 0.66  ┆ 6.6       ┆ 10.0      ┆ 0x17e0a0f │
# │ T05:16:03. ┆           ┆ d1c97e853c ┆ e472b542e1 ┆   ┆       ┆           ┆           ┆ 9d6745325 │
# │ 000000     ┆           ┆ 6e0f03ad3c ┆ df039594ee ┆   ┆       ┆           ┆           ┆ 94ef93328 │
# │            ┆           ┆ …          ┆ …          ┆   ┆       ┆           ┆           ┆ 5da…      │
# │ 2025-11-09 ┆ 668921    ┆ 0x6031b6ee ┆ 0x537494c5 ┆ … ┆ 0.91  ┆ 9.1       ┆ 10.0      ┆ 0x8acde1f │
# │ T05:16:03. ┆           ┆ d1c97e853c ┆ 4dee916253 ┆   ┆       ┆           ┆           ┆ eb5527895 │
# │ 000000     ┆           ┆ 6e0f03ad3c ┆ 4675712f2e ┆   ┆       ┆           ┆           ┆ abf9162d7 │
# │            ┆           ┆ …          ┆ …          ┆   ┆       ┆           ┆           ┆ 9b8…      │
# │ 2025-11-09 ┆ 672019    ┆ 0xb8d7c642 ┆ 0x4bfb41d5 ┆ … ┆ 0.5   ┆ 263.0     ┆ 526.0     ┆ 0x2adc7e4 │
# │ T05:16:03. ┆           ┆ 2b4ce8b89b ┆ b3570defd0 ┆   ┆       ┆           ┆           ┆ 1da8eaf30 │
# │ 000000     ┆           ┆ a25791f5b5 ┆ 3c39a9a4d8 ┆   ┆       ┆           ┆           ┆ 28924fc3e │
# │            ┆           ┆ …          ┆ …          ┆   ┆       ┆           ┆           ┆ e78…      │
# └────────────┴───────────┴────────────┴────────────┴───┴───────┴───────────┴───────────┴───────────┘

# %%
summary = latest_trades.select(
    pl.len().alias("rows"),
    pl.col("timestamp").min().alias("first_trade"),
    pl.col("timestamp").max().alias("last_trade"),
    pl.col("maker").n_unique().alias("unique_makers"),
    pl.col("taker").n_unique().alias("unique_takers"),
    pl.col("market_id").n_unique().alias("unique_markets"),
    pl.col("usd_amount").sum().alias("total_usd_volume"),
).collect()
summary
# Out:
# shape: (1, 7)
# ┌──────────┬──────────────┬──────────────┬──────────────┬──────────────┬─────────────┬─────────────┐
# │ rows     ┆ first_trade  ┆ last_trade   ┆ unique_maker ┆ unique_taker ┆ unique_mark ┆ total_usd_v │
# │ ---      ┆ ---          ┆ ---          ┆ s            ┆ s            ┆ ets         ┆ olume       │
# │ u32      ┆ str          ┆ str          ┆ ---          ┆ ---          ┆ ---         ┆ ---         │
# │          ┆              ┆              ┆ u32          ┆ u32          ┆ u32         ┆ f64         │
# ╞══════════╪══════════════╪══════════════╪══════════════╪══════════════╪═════════════╪═════════════╡
# │ 10000000 ┆ 2025-11-09T0 ┆ 2025-11-16T0 ┆ 222946       ┆ 206061       ┆ 18920       ┆ 8.4689e8    │
# │          ┆ 5:16:03.0000 ┆ 5:23:41.0000 ┆              ┆              ┆             ┆             │
# │          ┆ 00           ┆ 00           ┆              ┆              ┆             ┆             │
# └──────────┴──────────────┴──────────────┴──────────────┴──────────────┴─────────────┴─────────────┘

# %%
direction_stats = (
    latest_trades
    .group_by("maker_direction")
    .agg(
        pl.len().alias("num_trades"),
        pl.col("usd_amount").sum().alias("usd_volume"),
    )
    .with_columns(
        (pl.col("num_trades") / pl.col("num_trades").sum()).alias("trade_pct"),
        (pl.col("usd_volume") / pl.col("usd_volume").sum()).alias("usd_pct"),
    )
)
direction_stats.collect()
# Out:
# shape: (2, 5)
# ┌─────────────────┬────────────┬────────────┬───────────┬──────────┐
# │ maker_direction ┆ num_trades ┆ usd_volume ┆ trade_pct ┆ usd_pct  │
# │ ---             ┆ ---        ┆ ---        ┆ ---       ┆ ---      │
# │ str             ┆ u32        ┆ f64        ┆ f64       ┆ f64      │
# ╞═════════════════╪════════════╪════════════╪═══════════╪══════════╡
# │ SELL            ┆ 2272947    ┆ 1.9270e8   ┆ 0.2272947 ┆ 0.227539 │
# │ BUY             ┆ 7727053    ┆ 6.5419e8   ┆ 0.772705  ┆ 0.772461 │
# └─────────────────┴────────────┴────────────┴───────────┴──────────┘

# %%
maker_stats = (
    latest_trades
    .group_by("maker")
    .agg(
        pl.len().alias("num_trades"),
        pl.col("usd_amount").sum().alias("usd_volume"),
        pl.col("usd_amount").median().alias("median_usd_trade"),
        pl.col("market_id").n_unique().alias("unique_markets"),
        pl.col("maker_direction").eq("BUY").mean().alias("buy_ratio"),
    )
    .sort("usd_volume", descending=True)
    .limit(25)
)
maker_stats.collect().to_pandas()
# Out:
#                                          maker  num_trades    usd_volume  \
# 0   0x31519628fb5e5aa559d4ba27aa1248810b9f0977        9238  1.790610e+07
# 1   0x3657862e57070b82a289b5887ec943a7c2166b14         871  7.277952e+06
# 2   0xed88d69d689f3e2f6d1f77b2e35d089c581df3c4        2986  7.018110e+06
# 3   0x0d3b10b8eac8b089c6e4a695e65d8e044167c46b        7112  6.716128e+06
# 4   0xd218e474776403a330142299f7796e8ba32eb5c9       50367  5.581981e+06
# 5   0xe8dd7741ccb12350957ec71e9ee332e0d1e6ec86       84560  5.526548e+06
# 6   0x16b29c50f2439faf627209b2ac0c7bbddaa8a881        7300  5.346735e+06
# 7   0xee613b3fc183ee44f9da9c05f53e2da107e3debf       16857  4.820364e+06
# 8   0x2a923d2f6edbc894e76357104e654b27a0d9071e       17801  4.808154e+06
# 9   0x847b8fdacd157191d47c7ccb2aad5c67bbd21027        6023  4.273577e+06
# 10  0xa676582530fb1a63502d5f5f5db9fb8d1449e38b        4457  4.253619e+06
# 11  0x751a2b86cab503496efd325c8344e10159349ea1        5449  4.238267e+06
# 12  0x39871d481a332c4fd8f19e8ae35c9e17438b259e        3480  4.219646e+06
# 13  0x204f72f35326db932158cba6adff0b9a1da95e14       39120  4.151237e+06
# 14  0x507e52ef684ca2dd91f90a9d26d149dd3288beae       18111  4.013353e+06
# 15  0xee00ba338c59557141789b127927a55f5cc5cea1        2335  3.997234e+06
# 16  0xc3c3b3ef304ddbea39fa2246e683a71da5d0eec8        6622  3.994839e+06
# 17  0x2f09642639aedd6ced432519c1a86e7d52034632        2174  3.973057e+06
# 18  0x76062e7bbfc0fb783487ff884960c4bc17962836         739  3.805780e+06
# 19  0x21504551452f4c4b67a1fbee6ba743a611cdba16       78095  3.720374e+06
# 20  0xb744f56635b537e859152d14b022af5afe485210        1350  3.567668e+06
# 21  0x83b9f9e2d28ab875b9c9f73cdd5535c4c8926124       23489  3.369011e+06
# 22  0x743510ee9f21e24071c4e28edab4653df44ea620         159  3.345703e+06
# 23  0x5248313731287b61d714ab9df655442d6ed28aa2      182082  3.297353e+06
# 24  0x2005d16a84ceefa912d4e380cd32e7ff827875ea       31330  3.248989e+06
#
#     median_usd_trade  unique_markets  buy_ratio
# 0          56.999700             278   0.974670
# 1          65.263157              16   0.995408
# 2          40.843535              42   0.985934
# 3          26.555000              33   0.833521
# 4          22.494920            2141   0.999960
# 5          25.579248            3313   0.999515
# 6          23.500000             480   1.000000
# 7          15.333333            1418   1.000000
# 8          31.590000             282   1.000000
# 9         104.646000              57   0.447451
# 10        626.109000             715   0.994840
# 11         47.312640             941   1.000000
# 12         23.480000              26   0.999425
# 13         15.080000             969   1.000000
# 14         26.325000             875   0.751974
# 15         69.300000             139   0.923769
# 16         17.213772             282   0.969345
# 17         60.000000              84   0.809108
# 18         46.200000              28   0.940460
# 19         21.250000            3256   1.000000
# 20         31.617307              27   0.960741
# 21         14.400000             498   0.996935
# 22        294.000000               2   0.968553
# 23          7.250000            1889   1.000000
# 24         14.390243             716   0.998851

# %%
markets_df = (
    pl.scan_csv('../markets.csv')
    .select(
        pl.col('id').alias('market_id'),
        pl.col('question'),
        pl.col('answer1'),
        pl.col('answer2'),
        pl.col('ticker'),
    )
)

top_markets = (
    latest_trades
    .group_by('market_id')
    .agg(
        pl.len().alias('num_trades'),
        pl.col('usd_amount').sum().alias('usd_volume'),
        pl.col('price').mean().alias('avg_price'),
    )
    .sort('usd_volume', descending=True)
    .limit(20)
    .join(markets_df, on='market_id', how='left')
)
top_markets.collect()
# Out:
# shape: (20, 8)
# ┌───────────┬────────────┬────────────┬───────────┬────────────┬───────────┬───────────┬───────────┐
# │ market_id ┆ num_trades ┆ usd_volume ┆ avg_price ┆ question   ┆ answer1   ┆ answer2   ┆ ticker    │
# │ ---       ┆ ---        ┆ ---        ┆ ---       ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │ i64       ┆ u32        ┆ f64        ┆ f64       ┆ str        ┆ str       ┆ str       ┆ str       │
# ╞═══════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 660880    ┆ 62921      ┆ 2.3927e7   ┆ 0.52098   ┆ LoL: T1 vs ┆ T1        ┆ KT        ┆ lol-t1-kt │
# │           ┆            ┆            ┆           ┆ KT Rolster ┆           ┆ Rolster   ┆ -2025-11- │
# │           ┆            ┆            ┆           ┆ (BO5)      ┆           ┆           ┆ 09        │
# │ 570363    ┆ 37647      ┆ 1.4127e7   ┆ 0.467425  ┆ Fed        ┆ Yes       ┆ No        ┆ fed-decis │
# │           ┆            ┆            ┆           ┆ increases  ┆           ┆           ┆ ion-in-de │
# │           ┆            ┆            ┆           ┆ interest   ┆           ┆           ┆ cember    │
# │           ┆            ┆            ┆           ┆ rates b…   ┆           ┆           ┆           │
# │ 673597    ┆ 44810      ┆ 1.2907e7   ┆ 0.518747  ┆ Will the   ┆ Yes       ┆ No        ┆ what-day- │
# │           ┆            ┆            ┆           ┆ government ┆           ┆           ┆ will-the- │
# │           ┆            ┆            ┆           ┆ shutdown   ┆           ┆           ┆ governmen │
# │           ┆            ┆            ┆           ┆ e…         ┆           ┆           ┆ t-s…      │
# │ 570360    ┆ 48556      ┆ 1.1667e7   ┆ 0.592099  ┆ Fed        ┆ Yes       ┆ No        ┆ fed-decis │
# │           ┆            ┆            ┆           ┆ decreases  ┆           ┆           ┆ ion-in-de │
# │           ┆            ┆            ┆           ┆ interest   ┆           ┆           ┆ cember    │
# │           ┆            ┆            ┆           ┆ rates b…   ┆           ┆           ┆           │
# │ 623603    ┆ 48141      ┆ 8.9632e6   ┆ 0.602383  ┆ Will the   ┆ Yes       ┆ No        ┆ when-will │
# │           ┆            ┆            ┆           ┆ Government ┆           ┆           ┆ -the-gove │
# │           ┆            ┆            ┆           ┆ shutdown   ┆           ┆           ┆ rnment-sh │
# │           ┆            ┆            ┆           ┆ e…         ┆           ┆           ┆ utd…      │
# │ …         ┆ …          ┆ …          ┆ …         ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 673151    ┆ 9600       ┆ 4.4225e6   ┆ 0.499107  ┆ Clemson    ┆ Clemson   ┆ Louisvill ┆ cfb-clmsn │
# │           ┆            ┆            ┆           ┆ vs.        ┆           ┆ e         ┆ -lou-2025 │
# │           ┆            ┆            ┆           ┆ Louisville ┆           ┆           ┆ -11-14    │
# │ 669365    ┆ 16662      ┆ 4.3986e6   ┆ 0.524203  ┆ Hawks vs.  ┆ Hawks     ┆ Jazz      ┆ nba-atl-u │
# │           ┆            ┆            ┆           ┆ Jazz       ┆           ┆           ┆ ta-2025-1 │
# │           ┆            ┆            ┆           ┆            ┆           ┆           ┆ 1-13      │
# │ 674632    ┆ 13531      ┆ 4.3943e6   ┆ 0.470431  ┆ UFC 322:   ┆ Makhachev ┆ Della     ┆ ufc-isl-j │
# │           ┆            ┆            ┆           ┆ Makhachev  ┆           ┆ Maddalena ┆ ac9-2025- │
# │           ┆            ┆            ┆           ┆ vs. Della  ┆           ┆           ┆ 11-15     │
# │           ┆            ┆            ┆           ┆ M…         ┆           ┆           ┆           │
# │ 551963    ┆ 13365      ┆ 4.3815e6   ┆ 0.855918  ┆ Xi Jinping ┆ Yes       ┆ No        ┆ xi-jinpin │
# │           ┆            ┆            ┆           ┆ out in     ┆           ┆           ┆ g-out-in- │
# │           ┆            ┆            ┆           ┆ 2025?      ┆           ┆           ┆ 2025      │
# │ 660431    ┆ 6448       ┆ 4.3475e6   ┆ 0.527983  ┆ Steelers   ┆ Steelers  ┆ Chargers  ┆ nfl-pit-l │
# │           ┆            ┆            ┆           ┆ vs.        ┆           ┆           ┆ ac-2025-1 │
# │           ┆            ┆            ┆           ┆ Chargers   ┆           ┆           ┆ 1-09      │
# └───────────┴────────────┴────────────┴───────────┴────────────┴───────────┴───────────┴───────────┘

# %%
latest_trades.tail(5).collect()
# Out:
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬──────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ market_id ┆ maker     ┆ taker     ┆ … ┆ price    ┆ usd_amoun ┆ token_amo ┆ transacti │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---      ┆ t         ┆ unt       ┆ onHash    │
# │ str       ┆ i64       ┆ str       ┆ str       ┆   ┆ f64      ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆           ┆           ┆   ┆          ┆ f64       ┆ f64       ┆ str       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-11-1 ┆ 672859    ┆ 0xfb1c3c1 ┆ 0x9faaac0 ┆ … ┆ 0.541    ┆ 141.15772 ┆ 260.92    ┆ 0x4f705f0 │
# │ 6T05:23:4 ┆           ┆ ab4fb2d0c ┆ 3eeab1db2 ┆   ┆          ┆           ┆           ┆ 684ec99f9 │
# │ 1.000000  ┆           ┆ bcbb9538c ┆ 2065be31f ┆   ┆          ┆           ┆           ┆ 2ee205a4a │
# │           ┆           ┆ 8d4…      ┆ 673…      ┆   ┆          ┆           ┆           ┆ 204…      │
# │ 2025-11-1 ┆ 672859    ┆ 0x9faaac0 ┆ 0xc5d563a ┆ … ┆ 0.541526 ┆ 297.83908 ┆ 550.0     ┆ 0x4f705f0 │
# │ 6T05:23:4 ┆           ┆ 3eeab1db2 ┆ 36ae78145 ┆   ┆          ┆           ┆           ┆ 684ec99f9 │
# │ 1.000000  ┆           ┆ 2065be31f ┆ c45a50134 ┆   ┆          ┆           ┆           ┆ 2ee205a4a │
# │           ┆           ┆ 673…      ┆ d48…      ┆   ┆          ┆           ┆           ┆ 204…      │
# │ 2025-11-1 ┆ 674632    ┆ 0x824de04 ┆ 0x4bfb41d ┆ … ┆ 0.28     ┆ 190.99999 ┆ 682.14285 ┆ 0x94b2858 │
# │ 6T05:23:4 ┆           ┆ 778b34a1e ┆ 5b3570def ┆   ┆          ┆ 9         ┆ 6         ┆ d8535b938 │
# │ 1.000000  ┆           ┆ 63d57bb69 ┆ d03c39a9a ┆   ┆          ┆           ┆           ┆ 609829c37 │
# │           ┆           ┆ 7fc…      ┆ 4d8…      ┆   ┆          ┆           ┆           ┆ 67b…      │
# │ 2025-11-1 ┆ 674632    ┆ 0xdbade4c ┆ 0x824de04 ┆ … ┆ 0.72     ┆ 491.14285 ┆ 682.14285 ┆ 0x94b2858 │
# │ 6T05:23:4 ┆           ┆ 82fb72780 ┆ 778b34a1e ┆   ┆          ┆ 7         ┆ 6         ┆ d8535b938 │
# │ 1.000000  ┆           ┆ a0db9a38f ┆ 63d57bb69 ┆   ┆          ┆           ┆           ┆ 609829c37 │
# │           ┆           ┆ 821…      ┆ 7fc…      ┆   ┆          ┆           ┆           ┆ 67b…      │
# │ 2025-11-1 ┆ 570363    ┆ 0xe233774 ┆ 0xc5d563a ┆ … ┆ 0.995    ┆ 114.65982 ┆ 115.236   ┆ 0xd9e9cdb │
# │ 6T05:23:4 ┆           ┆ dc4b736bc ┆ 36ae78145 ┆   ┆          ┆           ┆           ┆ 1fb033e13 │
# │ 1.000000  ┆           ┆ 315f1efad ┆ c45a50134 ┆   ┆          ┆           ┆           ┆ 143a28322 │
# │           ┆           ┆ c1e…      ┆ d48…      ┆   ┆          ┆           ┆           ┆ 395…      │
# └───────────┴───────────┴───────────┴───────────┴───┴──────────┴───────────┴───────────┴───────────┘
